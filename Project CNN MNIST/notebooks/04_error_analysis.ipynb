# %% [markdown]
# # Error Analysis Notebook
#
# **Purpose**: Analyze model errors, generate confusion matrix, and identify misclassified patterns
#
# **Outputs**: Confusion matrix visualization, per-class metrics, error distribution analysis

# %% [markdown]
# ## 1. Load Model and Data

# %% [markdown]
# ## 2. Generate Predictions

# %% [markdown]
# ## 3. Confusion Matrix

# %% [markdown]
# ## 4. Per-Class Metrics

# %% [markdown]
# ## 5. Error Distribution Analysis

# %% [markdown]
# # Error Analysis
#
# **Purpose**: Analyze model errors and misclassifications
#
# **Outputs**: Confusion matrix, error samples, error distribution analysis

# %% [markdown]
# ## 1. Load Model and Data

# %% [markdown]
# ## 2. Run Inference on Test Set

# %% [markdown]
# # Compute confusion matrix
# cm = confusion_matrix(all_labels, all_preds)
#
# # Visualize
# plt.figure(figsize=(10, 8))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True,
#             xticklabels=range(10), yticklabels=range(10))
# plt.xlabel('Predicted Label', fontsize=12)
# plt.ylabel('True Label', fontsize=12)
# plt.title('Confusion Matrix - Test Set', fontsize=14, fontweight='bold')
# plt.tight_layout()
# plt.savefig('notebooks/assets/figures/confusion_matrix.png', dpi=150, bbox_inches='tight')
# plt.show()
#
# print("✓ Confusion matrix saved")
